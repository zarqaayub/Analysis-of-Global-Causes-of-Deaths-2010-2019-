# %%
# import libraries
import pandas as pd 
import numpy as np
import os

# %%
# import data set
path = r'C:\Users\Zarqa Ayub\Achievement 6'

# %%
df=pd.read_csv(os.path.join(path,'02. Data', 'Original Data', 'cause_of_deaths.csv'),index_col=0)

# %%
# Check data set
df.head()
# Out:
#                   Code  Year  Meningitis  \
# Country/Territory
# Afghanistan        AFG  1990        2159
# Afghanistan        AFG  1991        2218
# Afghanistan        AFG  1992        2475
# Afghanistan        AFG  1993        2812
# Afghanistan        AFG  1994        3027
#
#                    Alzheimer's Disease and Other Dementias  \
# Country/Territory
# Afghanistan                                           1116
# Afghanistan                                           1136
# Afghanistan                                           1162
# Afghanistan                                           1187
# Afghanistan                                           1211
#
#                    Parkinson's Disease  Nutritional Deficiencies  Malaria  \
# Country/Territory
# Afghanistan                        371                      2087       93
# Afghanistan                        374                      2153      189
# ...

# %%
# view last 5 rows
df.tail()
# Out:
#                   Code  Year  Meningitis  \
# Country/Territory
# Zimbabwe           ZWE  2015        1439
# Zimbabwe           ZWE  2016        1457
# Zimbabwe           ZWE  2017        1460
# Zimbabwe           ZWE  2018        1450
# Zimbabwe           ZWE  2019        1450
#
#                    Alzheimer's Disease and Other Dementias  \
# Country/Territory
# Zimbabwe                                               754
# Zimbabwe                                               767
# Zimbabwe                                               781
# Zimbabwe                                               795
# Zimbabwe                                               812
#
#                    Parkinson's Disease  Nutritional Deficiencies  Malaria  \
# Country/Territory
# Zimbabwe                           215                      3019     2518
# Zimbabwe                           219                      3056     2050
# ...

# %%
# view dimensions
df.shape
# Out:
# (6120, 33)

# %%
#check column names
df.columns
# Out:
# Index(['Code', 'Year', 'Meningitis', 'Alzheimer's Disease and Other Dementias',
#        'Parkinson's Disease', 'Nutritional Deficiencies', 'Malaria',
#        'Drowning', 'Interpersonal Violence', 'Maternal Disorders', 'HIV/AIDS',
#        'Drug Use Disorders', 'Tuberculosis', 'Cardiovascular Diseases',
#        'Lower Respiratory Infections', 'Neonatal Disorders',
#        'Alcohol Use Disorders', 'Self-harm', 'Exposure to Forces of Nature',
#        'Diarrheal Diseases', 'Environmental Heat and Cold Exposure',
#        'Neoplasms', 'Conflict and Terrorism', 'Diabetes Mellitus',
#        'Chronic Kidney Disease', 'Poisonings', 'Protein-Energy Malnutrition',
#        'Road Injuries', 'Chronic Respiratory Diseases',
#        'Cirrhosis and Other Chronic Liver Diseases', 'Digestive Diseases',
#        'Fire, Heat, and Hot Substances', 'Acute Hepatitis'],
#       dtype='object')

# %%
# view data types
df.dtypes
# Out:
# Code                                          object
# Year                                           int64
# Meningitis                                     int64
# Alzheimer's Disease and Other Dementias        int64
# Parkinson's Disease                            int64
# Nutritional Deficiencies                       int64
# Malaria                                        int64
# Drowning                                       int64
# Interpersonal Violence                         int64
# Maternal Disorders                             int64
# HIV/AIDS                                       int64
# Drug Use Disorders                             int64
# Tuberculosis                                   int64
# Cardiovascular Diseases                        int64
# Lower Respiratory Infections                   int64
# Neonatal Disorders                             int64
# Alcohol Use Disorders                          int64
# Self-harm                                      int64
# ...

# %%
# view all the unique values in the column years
df['Year'].unique()
# Out:
# array([1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#        2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], dtype=int64)

# %% [markdown]
# ### Create the Data frame (2010-2019)

# %%
# filter the rows to include only 2010-2019 years
df_filter=df[df['Year']>2009]
df_filter
# Out:
#                   Code  Year  Meningitis  \
# Country/Territory
# Afghanistan        AFG  2010        2410
# Afghanistan        AFG  2011        2327
# Afghanistan        AFG  2012        2254
# Afghanistan        AFG  2013        2281
# Afghanistan        AFG  2014        1935
# ...                ...   ...         ...
# Zimbabwe           ZWE  2015        1439
# Zimbabwe           ZWE  2016        1457
# Zimbabwe           ZWE  2017        1460
# Zimbabwe           ZWE  2018        1450
# Zimbabwe           ZWE  2019        1450
#
#                    Alzheimer's Disease and Other Dementias  \
# Country/Territory
# Afghanistan                                           1476
# Afghanistan                                           1508
# Afghanistan                                           1544
# Afghanistan                                           1581
# Afghanistan                                           1620
# ...                                                    ...
# ...

# %%
#check the result
df_filter['Year'].unique()
# Out:
# array([2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019],
#       dtype=int64)

# %%
df_filter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2040 entries, Afghanistan to Zimbabwe
# Data columns (total 33 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Code                                        2040 non-null   object
#  1   Year                                        2040 non-null   int64
#  2   Meningitis                                  2040 non-null   int64
#  3   Alzheimer's Disease and Other Dementias     2040 non-null   int64
#  4   Parkinson's Disease                         2040 non-null   int64
#  5   Nutritional Deficiencies                    2040 non-null   int64
#  6   Malaria                                     2040 non-null   int64
#  7   Drowning                                    2040 non-null   int64
#  8   Interpersonal Violence                      2040 non-null   int64
#  9   Maternal Disorders                          2040 non-null   int64
# ...

# %%
# calculate descriptive statistics
df_filter.describe(include='all')
# Out:
#         Code         Year    Meningitis  \
# count   2040  2040.000000   2040.000000
# unique   204          NaN           NaN
# top      AFG          NaN           NaN
# freq      10          NaN           NaN
# mean     NaN  2014.500000   1356.107353
# std      NaN     2.872986   5204.688616
# min      NaN  2010.000000      0.000000
# 25%      NaN  2012.000000     10.000000
# 50%      NaN  2014.500000     75.500000
# 75%      NaN  2017.000000    579.000000
# max      NaN  2019.000000  56658.000000
#
#         Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# count                               2040.000000          2040.000000
# unique                                      NaN                  NaN
# top                                         NaN                  NaN
# freq                                        NaN                  NaN
# mean                                6760.061275          1556.911765
# ...

# %%
# set the display options to show all columns
pd.set_option('display.max_columns', None)

# %%
df_filter.describe()
# Out:
#               Year    Meningitis  Alzheimer's Disease and Other Dementias  \
# count  2040.000000   2040.000000                              2040.000000
# mean   2014.500000   1356.107353                              6760.061275
# std       2.872986   5204.688616                             24616.044665
# min    2010.000000      0.000000                                 0.000000
# 25%    2012.000000     10.000000                               128.000000
# 50%    2014.500000     75.500000                               924.000000
# 75%    2017.000000    579.000000                              3494.750000
# max    2019.000000  56658.000000                            320715.000000
#
#        Parkinson's Disease  Nutritional Deficiencies        Malaria  \
# count          2040.000000               2040.000000    2040.000000
# mean           1556.911765               1391.966667    3592.322059
# std            5939.466903               4044.910891   17089.704099
# ...

# %% [markdown]
# I checked for inconsistencies such as negative values, large values or unexpected values for year column but none of them encounterd.

# %%
# Look for missing values
df_filter.isnull().sum()
# Out:
# Code                                          0
# Year                                          0
# Meningitis                                    0
# Alzheimer's Disease and Other Dementias       0
# Parkinson's Disease                           0
# Nutritional Deficiencies                      0
# Malaria                                       0
# Drowning                                      0
# Interpersonal Violence                        0
# Maternal Disorders                            0
# HIV/AIDS                                      0
# Drug Use Disorders                            0
# Tuberculosis                                  0
# Cardiovascular Diseases                       0
# Lower Respiratory Infections                  0
# Neonatal Disorders                            0
# Alcohol Use Disorders                         0
# Self-harm                                     0
# Exposure to Forces of Nature                  0
# Diarrheal Diseases                            0
# ...

# %% [markdown]
# no missing values found.

# %%
# Check for mixed-type data
for col in df_filter.columns.tolist():
  weird = (df_filter[[col]].applymap(type) != df_filter[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_filter[weird]) > 0:
    print (col)

# %% [markdown]
# No mixed type data found

# %%
# Look for duplicates
df_filter.duplicated().value_counts()
# Out:
# False    2040
# Name: count, dtype: int64

# %%
# Check the NaN
df_filter.isna().any().any()
# Out:
# False

# %% [markdown]
# There is no NaN values.

# %% [markdown]
# ### Reduce Memory usage
# I will use Klib library to change data types to reduce memory usage.

# %%
pip install klib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import klib

# %%
# Change data types
df_filter=klib.convert_datatypes(df_filter)

# %%
df_filter.dtypes
# Out:
# Code                                          string[python]
# Year                                                   int16
# Meningitis                                             int32
# Alzheimer's Disease and Other Dementias                int32
# Parkinson's Disease                                    int32
# Nutritional Deficiencies                               int32
# Malaria                                                int32
# Drowning                                               int32
# Interpersonal Violence                                 int32
# Maternal Disorders                                     int32
# HIV/AIDS                                               int32
# Drug Use Disorders                                     int32
# Tuberculosis                                           int32
# Cardiovascular Diseases                                int32
# Lower Respiratory Infections                           int32
# ...

# %%
# Save filtered data frame
df_filter.to_csv(os.path.join(path,'02. data','prepared data','cause_of_deaths_2010_2019.csv'))
